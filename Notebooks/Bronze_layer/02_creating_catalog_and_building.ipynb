# %%
# %sql
CREATE CATALOG IF NOT EXISTS github_lakehouse;

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS github_lakehouse.bronze;
CREATE SCHEMA IF NOT EXISTS github_lakehouse.silver;
CREATE SCHEMA IF NOT EXISTS github_lakehouse.gold;

# %% [markdown]
# # Building Example

# %%
from pyspark.sql.functions import (
    col,
    current_timestamp
)

# %%
raw_path = "s3://tahmid-gharchive-lakehouse/raw/github/"

# %%
raw_df = (
    spark.read
        .option("recursiveFileLookup", "true")
        .text(raw_path)
)

# %%
display(raw_df.limit(5))

# %%
bronze_df = (
    raw_df
        .select(
            col("value").alias("raw_json"),
            col("_metadata.file_path").alias("_source_file"),
            col("_metadata.file_name").alias("_source_file_name"),
            current_timestamp().alias("_ingested_at")
        )
)

# %%
display(bronze_df.limit(10))
